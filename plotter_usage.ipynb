# %%
import pandas as pd
from plotter import TemporalPlots, DataPlotter

# %% [markdown]
# ## Data

# %%
import pandas as pd

data = [
    ["2024-11-08 09:15:23", "Alice", "Customer Support", 245],
    ["2024-11-08 09:22:10", "Bob", "Technical Issues", 180],
    ["2024-11-08 09:30:45", "Alice", "Billing", 320],
    ["2024-11-08 09:45:12", "Charlie", "Customer Support", 156],
    ["2024-11-08 10:05:33", "Bob", "Sales Inquiry", 289],
    ["2024-11-08 10:18:50", "Diana", "Technical Issues", 412],
    ["2024-11-08 10:35:22", "Alice", "Product Information", 198],
    ["2024-11-08 10:50:15", "Charlie", "Billing", 267],
    ["2024-11-08 11:10:40", "Bob", "Customer Support", 334],
    ["2024-11-08 11:28:05", "Diana", "Sales Inquiry", 221],
    ["2024-11-08 11:45:30", "Alice", "Technical Issues", 445],
    ["2024-11-08 12:15:18", "Charlie", "Product Information", 178],
    ["2024-11-08 12:35:42", "Bob", "Billing", 298],
    ["2024-11-08 13:05:55", "Diana", "Customer Support", 312],
    ["2024-11-08 13:30:20", "Alice", "Sales Inquiry", 256],
    ["2024-11-08 13:52:10", "Charlie", "Technical Issues", 389],
    ["2024-11-08 14:15:35", "Bob", "Product Information", 203],
    ["2024-11-08 14:38:48", "Diana", "Billing", 275],
    ["2024-11-08 15:02:15", "Alice", "Customer Support", 341],
    ["2024-11-08 15:28:30", "Charlie", "Sales Inquiry", 192],
       ["2024-11-08 09:15:23", "Alice", "Customer Support", 245],
    ["2024-11-08 09:22:10", "Bob", "Technical Issues", 180],
    ["2024-11-08 09:30:45", "Alice", "Billing", 320],
    ["2024-11-08 09:45:12", "Charlie", "Customer Support", 156],
    ["2024-11-08 10:05:33", "Bob", "Sales Inquiry", 250],
    ["2024-11-08 10:18:50", "Diana", "Technical Issues", 300],
    ["2024-11-08 10:35:22", "Alice", "Product Information", 200],
    ["2024-11-08 10:50:15", "Charlie", "Billing", 200],
    ["2024-11-08 11:10:40", "Bob", "Customer Support", 300],
    ["2024-11-08 11:28:05", "Diana", "Sales Inquiry", 320],
    ["2024-11-08 11:45:30", "Alice", "Technical Issues", 300],
    ["2024-11-08 12:15:18", "Charlie", "Product Information", 456],
    ["2024-11-08 12:35:42", "Bob", "Billing", 456],
    ["2024-11-08 13:05:55", "Diana", "Customer Support", 984],
    ["2024-11-08 13:30:20", "Alice", "Sales Inquiry", 256],
    ["2024-11-08 13:52:10", "Charlie", "Technical Issues", 400],
    ["2024-11-08 14:15:35", "Bob", "Product Information", 324],
    ["2024-11-08 14:38:48", "Diana", "Billing", 346],
    ["2024-11-08 15:02:15", "Alice", "Customer Support", 456],
    ["2024-11-08 15:28:30", "Charlie", "Sales Inquiry", 169],
    ["2024-11-07 09:15:23", "Alice", "Customer Support", 245],
    ["2024-11-07 10:30:45", "Alice", "Billing", 320],
    ["2024-11-07 14:22:10", "Alice", "Technical Issues", 180],
    ["2024-11-07 16:05:33", "Alice", "Sales Inquiry", 289],
    
    ["2024-11-07 09:45:12", "Bob", "Customer Support", 156],
    ["2024-11-07 11:18:50", "Bob", "Technical Issues", 412],
    ["2024-11-07 13:35:42", "Bob", "Billing", 298],
    ["2024-11-07 15:15:35", "Bob", "Product Information", 203],
    
    ["2024-11-07 10:50:15", "Charlie", "Billing", 267],
    ["2024-11-07 12:15:18", "Charlie", "Product Information", 178],
    ["2024-11-07 13:52:10", "Charlie", "Technical Issues", 389],
    ["2024-11-07 15:28:30", "Charlie", "Sales Inquiry", 192],
    
    ["2024-11-07 10:18:50", "Diana", "Technical Issues", 300],
    ["2024-11-07 11:28:05", "Diana", "Sales Inquiry", 221],
    ["2024-11-07 13:05:55", "Diana", "Customer Support", 312],
    ["2024-11-07 14:38:48", "Diana", "Billing", 275],
    
    ["2024-11-08 09:20:10", "Alice", "Billing", 310],
    ["2024-11-08 11:45:30", "Alice", "Technical Issues", 445],
    ["2024-11-08 13:30:20", "Alice", "Sales Inquiry", 256],
    ["2024-11-08 15:02:15", "Alice", "Customer Support", 341],
    
    ["2024-11-08 09:22:10", "Bob", "Technical Issues", 190],
    ["2024-11-08 11:10:40", "Bob", "Customer Support", 334],
    ["2024-11-08 12:35:42", "Bob", "Billing", 298],
    ["2024-11-08 14:50:20", "Bob", "Sales Inquiry", 280],
    
    ["2024-11-08 09:45:12", "Charlie", "Customer Support", 156],
    ["2024-11-08 12:15:18", "Charlie", "Product Information", 456],
    ["2024-11-08 13:52:10", "Charlie", "Technical Issues", 400],
    ["2024-11-08 15:28:30", "Charlie", "Sales Inquiry", 169],
    
    ["2024-11-08 10:18:50", "Diana", "Technical Issues", 300],
    ["2024-11-08 12:05:55", "Diana", "Customer Support", 984],
    ["2024-11-08 14:38:48", "Diana", "Billing", 346],
    ["2024-11-08 16:10:30", "Diana", "Product Information", 220],
]
data.extend(data)
df=pd.DataFrame(data, columns=["datetime", "agent", "topic", "duration"])
df.head()
# Out:
#               datetime    agent             topic  duration
# 0  2024-11-08 09:15:23    Alice  Customer Support       245
# 1  2024-11-08 09:22:10      Bob  Technical Issues       180
# 2  2024-11-08 09:30:45    Alice           Billing       320
# 3  2024-11-08 09:45:12  Charlie  Customer Support       156
# 4  2024-11-08 10:05:33      Bob     Sales Inquiry       289

# %% [markdown]
# ## Example usage

# %%
plotter=DataPlotter(df, category_col1='agent', category_col2='topic')
plotter.countplot('agent', figsize=(3,3))
# Out:
# (<Figure size 300x300 with 1 Axes>,
#  <Axes: title={'center': 'Count of agent'}, ylabel='agent'>)

# %%
plotter.countplot('dayofweek',figsize=(3,3))
# Out:
# (<Figure size 300x300 with 1 Axes>,
#  <Axes: title={'center': 'Count of dayofweek'}, ylabel='dayofweek'>)

# %%
plotter.category_mean_with_hdi('duration')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'mean of duration by agent'}, xlabel='agent', ylabel='mean duration'>)

# %%
plotter.category_mean_with_hdi('duration', kind='line')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'mean of duration by agent'}, xlabel='agent', ylabel='mean duration'>)

# %%
plotter.category_mean_by_group('duration')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'mean of duration by agent across topic'}, xlabel='topic', ylabel='mean duration'>)

# %%
plotter.category_mean_by_group('duration', kind='dot')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'mean of duration by agent across topic'}, xlabel='topic', ylabel='mean duration'>)

# %%
plotter.category_mean_by_group_faceted('duration', category_col='agent', facet_col='topic', x_axis='category')
# Out:
# (<Figure size 700x700 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}>,
#         <Axes: title={'center': 'Technical Issues'}>,
#         <Axes: title={'center': 'Billing'}>,
#         <Axes: title={'center': 'Sales Inquiry'}>,
#         <Axes: title={'center': 'Product Information'}>, <Axes: >],
#        dtype=object))

# %%
plotter.category_mean_by_group_faceted('duration', category_col='agent', facet_col='topic', x_axis='category',  treat_as_continuous=True)
# Out:
# (<Figure size 700x700 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}>,
#         <Axes: title={'center': 'Technical Issues'}>,
#         <Axes: title={'center': 'Billing'}>,
#         <Axes: title={'center': 'Sales Inquiry'}>,
#         <Axes: title={'center': 'Product Information'}>, <Axes: >],
#        dtype=object))

# %%
plotter.category_mean_by_group_faceted_multiline('duration', category_col='agent', facet_col='topic', group_by='dayofweek', treat_as_continuous=True)
# Out:
# (<Figure size 700x700 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}>,
#         <Axes: title={'center': 'Technical Issues'}>,
#         <Axes: title={'center': 'Billing'}>,
#         <Axes: title={'center': 'Sales Inquiry'}>,
#         <Axes: title={'center': 'Product Information'}>, <Axes: >],
#        dtype=object))

# %%
plotter.category_mean_by_group_faceted('duration', category_col='agent', facet_col='topic', x_axis='category')
# Out:
# (<Figure size 700x700 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}>,
#         <Axes: title={'center': 'Technical Issues'}>,
#         <Axes: title={'center': 'Billing'}>,
#         <Axes: title={'center': 'Sales Inquiry'}>,
#         <Axes: title={'center': 'Product Information'}>, <Axes: >],
#        dtype=object))

# %%
plotter.category_mean_by_group('duration', kind='dot')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'mean of duration by agent across topic'}, xlabel='topic', ylabel='mean duration'>)

# %%
plotter.temporal.mean_by_period_and_category('duration', period='h', show_hdi=True, figsize=(9,6))
# Out:
# (<Figure size 900x600 with 1 Axes>,
#  <Axes: title={'center': 'Mean of duration by agent per period h'}, xlabel='Period h', ylabel='Mean duration'>)

# %%
plotter.temporal.mean_by_period_and_categories('duration', period='h', show_hdi=True, figsize=(10,10))
# Out:
# (<Figure size 1000x1000 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Technical Issues'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Billing'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Sales Inquiry'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Product Information'}, xlabel='datetime'>,
#         <Axes: >], dtype=object))

# %%
plotter.temporal.mean_by_period_and_categories('duration', period='h', show_hdi=True, legend='bottom', ncols=2, figsize=(10, 8))
# Out:
# (<Figure size 1000x800 with 6 Axes>,
#  array([<Axes: title={'center': 'Customer Support'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Technical Issues'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Billing'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Sales Inquiry'}, xlabel='datetime'>,
#         <Axes: title={'center': 'Product Information'}, xlabel='datetime'>,
#         <Axes: >], dtype=object))

# %%
plotter.temporal.count_by_period_and_category(period='h', category_col='agent')
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'Count of agent per period of h'}, xlabel='Period h', ylabel='Count'>)

# %%
plotter.crosstab_heatmap(figsize=(3,3))
# Out:
# (<Figure size 300x300 with 2 Axes>, <Axes: xlabel='topic', ylabel='agent'>)

# %%
plotter.countplot('day', figsize=(3,3))
# Out:
# (<Figure size 300x300 with 1 Axes>,
#  <Axes: title={'center': 'Count of day'}, ylabel='day'>)

# %%
plotter.temporal.count_by_period(period='h', figsize=(3,3))
# Out:
# (<Figure size 300x300 with 1 Axes>,
#  <Axes: title={'center': 'Count per period h'}, xlabel='period h', ylabel='Count'>)

# %%
plotter.temporal.count_by_period(period='s', figsize=(3,3))
# Out:
# (<Figure size 300x300 with 1 Axes>,
#  <Axes: title={'center': 'Count per period s'}, xlabel='period s', ylabel='Count'>)
